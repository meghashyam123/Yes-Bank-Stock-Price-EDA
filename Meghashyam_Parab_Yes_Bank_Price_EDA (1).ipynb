# %% [markdown]
# # **Project Name**    - Yes Bank Stock EDA

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### Team Member 1 -Meghashyam Parab

# %% [markdown]
# # Project Summary -

# %% [markdown]
# 📊 Yes Bank Stock Analysis – Exploratory Data Analysis (EDA)
#
#
#
#
#
# Overview
#
# This project performs an Exploratory Data Analysis (EDA) on Yes Bank’s historical stock prices to uncover key insights, trends, and volatility. Using Python, Pandas, Matplotlib, and Seaborn, we analyze stock performance and daily returns to help investors and analysts make informed decisions.
#
# Objectives :
#
#
# ✔️ Understand historical price trends 📈
#
# ✔️ Analyze daily returns and stock volatility 📊
#
# ✔️ Identify potential investment risks and opportunities 💡
#
# ✔️ Visualize insights using interactive plots 🎨
#
# ---
#
# Key Insights :
#
# 🔹 Trend Analysis – Identifying long-term growth or decline.
#
# 🔹 Volatility Study – Measuring fluctuations in stock prices.
#
# 🔹 Return Analysis – Understanding profitability and risk.
#
# 🔹 Seasonality Check – Detecting patterns over time.
#
#
#
# -----
#
#
# Technologies Used :
#
# 🔹 Python – Data manipulation & analysis
#
# 🔹 Pandas & NumPy – Data processing
#
# 🔹 Matplotlib & Seaborn – Data visualization

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/meghashyam123/Yes-Bank-Stock-Price-EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# This exploratory data analysis (EDA) aims to uncover key trends in Yes Bank’s stock performance over time. By analyzing historical prices, volatility, and returns, we seek to identify patterns, potential risks, and investment opportunities. Through visual storytelling and data-driven insights, this study will help investors and analysts make informed decisions in an ever-evolving financial landscape. 🚀📊

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary objective of this analysis is to understand the historical performance, volatility, and trends in Yes Bank’s stock prices. By leveraging exploratory data analysis (EDA), we aim to:
#
# ✅ Identify price patterns and trends over time.
#
# ✅ Analyze daily returns and stock volatility to assess risk.
#
# ✅ Discover seasonal or market-driven fluctuations.
#
# ✅ Provide data-driven insights for investors and analysts to make informed decisions.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries


#Let's import the modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import missingno as msno
import yfinance as yf




import plotly.express as px
import plotly.graph_objects as go

# install and import sweetviz
import subprocess
batcmd = "pip install sweetviz"
result = subprocess.check_output(batcmd, shell=True)
import sweetviz as sv




from sklearn.model_selection import cross_val_score, GridSearchCV
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

stock_df = pd.read_csv('/content/data_YesBank_StockPrices.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

stock_df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

stock_df.columns

# %%
#Getting the shape of dataset with rows and columns
print(stock_df.shape)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

stock_df.info()

# %%
#Looking for the description of the dataset to get insights of the data
stock_df.describe().T

# %% [markdown]
# #### Duplicate Values

# %%
# count null values
stock_df.isnull().sum()

# %%
# checking for duplicates
stock_df[stock_df.duplicated()==True]

# %%
print(f'Dataframe contains stock prices between {stock_df.Date.min()} to {stock_df.Date.max()}')

# %% [markdown]
# #### Missing Values/Null Values

# %%
# convert date column to proper format(YYYY-MM-DD)
from datetime import datetime
stock_df['Date'] = pd.to_datetime(stock_df['Date'].apply(lambda x: datetime.strptime(x, '%b-%y')))

# %%
stock_df.head(15)

# %%
# set date as an index
stock_df.set_index('Date',inplace=True)

# %%
stock_df.head()

# %%
# Visualizing the missing values

# Checking Null Value by plotting Heatmap
plt.figure(figsize = (10,5))
sns.heatmap(stock_df.isnull(), cbar=True, annot=False, yticklabels=False)
plt.title('Visualizing the missing values', fontsize = 15)

# %%
# visulization of Missing values
import missingno as msno


msno.bar(stock_df,figsize=(6,6))


plt.title('Missing Data bar Plot')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Dataset Overview:
#
# The dataset contains 185 rows and 5 columns.
# The columns are:
#
# Date: Monthly stock price date (format appears to be MMM-YY).
#
# Open: Opening price of Yes Bank stock.
#
# High: Highest stock price in that month.
#
# Low: Lowest stock price in that month.
#
# Close: Closing price of the stock.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
stock_df.columns

# %%
# Dataset Describe
stock_df.describe(include='all')

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Here’s a description of each variable in the dataset:
#
# Date (object):
# Represents the month and year of the stock data (e.g., "Jul-05" for July 2005).
# Likely in the format MMM-YY.
#
# Open (float):
# The price at which Yes Bank's stock opened for trading at the beginning of the month.
# Unit: Indian Rupees (₹).
#
# High (float):
# The highest price that Yes Bank's stock reached during the month.
# Unit: Indian Rupees (₹).
#
# Low (float):
# The lowest price that Yes Bank's stock reached during the month.
# Unit: Indian Rupees (₹).
#
# Close (float):
# The price at which Yes Bank's stock closed at the end of the month.
# Unit: Indian Rupees (₹).

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in stock_df.columns.tolist():
  print("unique value count in",i,"is",stock_df[i].nunique())

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
#copy of my dataset
stock_df_copy= stock_df.copy()

# %%
stock_df_copy.head()
stock_df_copy.isnull().sum()

# %%
len(stock_df_copy[stock_df_copy.duplicated()])

# %%
from datetime import datetime
# stock_df_copy['Date'] = pd.to_datetime(stock_df_copy['Date'].apply(lambda x: datetime.strptime(x,'%b-%y'))) # This line caused error
# Instead, access the index:
stock_df_copy.index = pd.to_datetime(stock_df_copy.index.to_series().apply(lambda x: datetime.strptime(x.strftime('%b-%y'),'%b-%y'))) # Apply datetime conversion to the index
stock_df_copy.head()

# %%
stock_df_copy.info()

# %%
stock_df_copy.describe()

# %%
col=stock_df_copy.columns.to_list()
numerical_cols=col[1:]

# %%
numerical_cols

# %%
#outlier detection
stock_df[['Open','High','Low','Close']].plot(kind='box')

# %%
# check for outliers in 'Open' , 'High', 'Low' and 'Close' columns
fig = plt.figure(figsize=(12,6))
c=1
for i in ['Open' , 'High', 'Low', 'Close'] :
    plt.subplot(2, 2, c)
    plt.xlabel(i, fontsize = 12)
    sns.boxplot(x=i,data=stock_df,color="tomato")
    c = c + 1
plt.tight_layout()

# %%
#create a function to find outliers using IQR

def find_outliers_IQR(df):
   q1=df.quantile(0.25)
   q3=df.quantile(0.75)
   IQR=q3-q1
   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]
   return outliers

# %%
# find outliers in percentage
for i in ['Open' , 'High', 'Low', 'Close']:
  outliers = find_outliers_IQR(stock_df[i])
  outliers_percent = round((outliers.size/stock_df[i].size)*100, 2)
  print(f'{i} : {outliers_percent}%')

# %%
# find outliers
for i in ['Open' , 'High', 'Low', 'Close']:
  outliers = find_outliers_IQR(stock_df[i])
  print(f'{i} : ')
  print(outliers)

# %%
# analyze outliers
stock_df[144:158]

# %%
# Function to extract year from the index (if it's a DatetimeIndex)
def extract_year_from_index(df):
  """
  Extracts the year from the index of a DataFrame if it's a DatetimeIndex.
  If the index is not a DatetimeIndex, it returns the original DataFrame.
  """
  if isinstance(df.index, pd.DatetimeIndex):
    df['Year'] = df.index.year  # Extract year from DatetimeIndex
  # Add handling for other index types if needed
  # For example: if it's a RangeIndex, you might want to provide a different behavior.
  return df

# Applying the function to extract the year
stock_df = extract_year_from_index(stock_df)

# check min, max and mean prices for each year
stock_df.groupby('Year').aggregate({'Open': [min, max, 'mean'], 'High': [min, max, 'mean'], 'Low': [min, max, 'mean'], 'Close': [min, max, 'mean']})

# %%
# Add a 'Month' column:
stock_df['Month'] = stock_df.index.month

# Calculate monthly statistics:
stock_df.groupby('Month').aggregate({'Open' : [np.min, np.max, np.mean], 'High' : [np.min, np.max, np.mean], 'Low' : [np.min, np.max, np.mean], 'Close' : [np.min, np.max, np.mean]})

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Data Manipulations Performed:
#
# Data Cleaning:
#
# *   Handled missing values and ensured data consistency.
# *   Converted date columns into a proper datetime format.
#
# Feature Engineering:
#
# Created new metrics like daily returns, moving averages, and volatility
#
# *   Created new metrics like daily returns, moving averages, and volatility indicators.
#
# *   Calculated monthly and yearly trends for better insights.
#
# Visualization & Trend Analysis:
#
# Line Chart: Analyzed stock price movement over time (Open, High, Low, Close).
#
# *   Line Chart: Analyzed stock price movement over time (Open, High, Low, Close).
#
# *   Heatmap: Correlation between different stock price metrics across years.
#
# *   Box Plot: Identified stock price distribution and outliers.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
sv.analyze(stock_df).show_notebook()

# %%
# visualizing price trend since 2005 to 2020
plt.figure(figsize = (10,5))
plt.plot(stock_df.index, stock_df['Open'] , label = 'open')
plt.plot(stock_df.index, stock_df['High'] , label = 'High')
plt.plot(stock_df.index, stock_df['Low'], label = 'Low')
plt.plot(stock_df.index, stock_df['Close'], label = 'Close')
plt.legend()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This line chart was chosen because it effectively visualizes long-term stock price trends, highlighting periods of growth, peak performance, and decline over time. The smooth flow of data makes it easy to analyze market movements, volatility, and major turning points in a single view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Steady Growth (2005-2017): The stock experienced a consistent upward trend, indicating strong market confidence and business growth.
#
# Peak Performance (2017-2018): The stock reached its highest value, showing a period of strong investor interest and high valuations.
#
# Sharp Decline (2019-2020): A drastic drop suggests a major financial crisis, governance issues, or external market shocks affecting the company.
#
# Volatility: The fluctuations in later years indicate uncertainty, possibly due to regulatory actions, economic downturns, or loss of investor trust.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact:
#
# *   The strong growth phase (2005-2017) indicates that the company had a successful business model, investor confidence, and market demand.
#
# *   Understanding the factors behind the peak performance (2017-2018) can help in formulating strategies to replicate that success in the future.
#
#
# Negative Impact & Justification:
#
# *   The sharp decline (2019-2020) signals potential issues like poor management decisions, financial instability, regulatory challenges, or market trust erosion.
#
# *   Investor confidence is lost, making it harder to attract future investments.
# The high volatility suggests a lack of stability, which can discourage long-term investors and impact overall business sustainability.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code


# Visualizing min, max and mean prices for each year
Year_prices_df = stock_df.groupby('Year').aggregate({'Open' : [min, max, 'mean'], 'High' : [min, max, 'mean'], 'Low' : [min, max, 'mean'], 'Close' : [min, max, 'mean']})
plt.figure(figsize = (12,8))
sns.heatmap(Year_prices_df , annot = True, cmap = 'coolwarm', fmt='.2f')
plt.xlabel('Min-Max-Mean')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the heatmap because it provides a clear visual representation of stock price trends over the years, highlighting patterns, volatility, and key turning points in a concise and interpretable manner. The color intensity effectively showcases periods of growth and decline, making it easier to identify significant financial trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.   Stock Price Growth Over Time 📈
#
#   *   From 2005 to 2019, there is a consistent increase in stock prices (open, high, low, and close values), peaking in 2018.
#
#   *   This indicates strong historical growth, reflecting positive investor confidence.
#
#
# 2.   Extreme Price Surge in 2018 🔺
#
#   *   The highest values across all categories (Open, High, Low, Close) occurred in 2018, with 404.00 as the High-Min value.
#
#   *   Suggests a bullish market with high volatility.
#
#
#
# 3.   Sharp Decline in 2019-2020 🔻
#
#   *   2020 shows a massive drop in stock values compared to previous years, signaling financial distress or external economic impacts.
#
#   *   The low closing prices (max: 22.11, min: 12.00) indicate that recovery was limited.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Aspects:
#
# *   Historical trends indicate strong past growth and market potential.
# *   Peak values in 2018 suggest investor confidence was at its highest.
#
# ❌ Negative Aspects:
#
# *   Massive fall in 2019-2020 implies financial instability, possibly due to regulatory, economic, or internal company issues.
#
# *   High volatility in recent years could reduce long-term investor trust.

# %% [markdown]
# #### Chart - 3

# %%
# Visualizing price trends of each year separately
import matplotlib.pyplot as plt

for year in stock_df['Year'].unique():
    year_data = stock_df[stock_df['Year'] == year]  # Filter data for the current year

    plt.figure(figsize=(10, 5))  # Create a new figure for each year
    plt.plot(year_data.index, year_data['Open'], label='Open')
    plt.plot(year_data.index, year_data['High'], label='High')
    plt.plot(year_data.index, year_data['Low'], label='Low')
    plt.plot(year_data.index, year_data['Close'], label='Close')

    plt.title(f'Yes Bank Stock Price Trend - {year}')  # Set title with year
    plt.xlabel('Date')
    plt.ylabel('Price (INR)')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This line chart was chosen to analyze the Yes Bank stock price trend in 2020 because:
#
#
#
# *  Clear Trend Analysis: It effectively visualizes stock price fluctuations over time, making it easier to identify significant peaks and drops.
#
# *  Crisis Impact: The sharp spike in March 2020 suggests a major event (possibly Yes Bank's financial crisis and RBI intervention).
#
# *  Comparative Analysis: The four key price points (Open, High, Low, Close) help in understanding volatility and investor sentiment.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   Sharp Price Surge in March 2020: The high price spiked significantly in March, likely due to external intervention (RBI’s rescue plan for Yes Bank).
#
# *   Steep Decline After March: Following the spike, stock prices dropped drastically and remained low for the rest of 2020, indicating continued investor skepticism.
#
# *   Volatility in Early 2020: Prices fluctuated significantly between January and April, showing market uncertainty.
#
# *   Stabilization at Lower Levels: After mid-2020, stock prices stabilized around INR 10-20, suggesting reduced trading interest and lower investor confidence.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Business Impact:
#
# Regulatory & Strategic Intervention Success: The sharp price surge in March suggests that Yes Bank’s revival strategy (possibly due to RBI’s intervention) momentarily restored investor confidence.
#
# Price Stabilization: Although stock prices declined, stabilization at lower levels indicates that extreme volatility reduced after the crisis, allowing for potential long-term recovery strategies.
#
# ❌ Negative Growth Insights & Justification:
#
# Steep Decline & Low Investor Confidence: The drastic price fall post-March and sustained low prices indicate that investor trust was not fully regained. This can limit the bank’s ability to raise capital or attract new investors.
#
# Long-Term Weak Performance: The stock did not recover significantly after the crash, showing that the bank struggled to generate market confidence despite interventions.
#
# High Volatility in Early 2020: Extreme fluctuations might have deterred institutional investors, leading to lower liquidity and reduced market interest.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# Visualizing Open, High, Low and Close average price  over months
stock_df.groupby('Month').aggregate({'Open' : 'mean', 'High' : 'mean', 'Low' : 'mean', 'Close' : 'mean'}).plot()
plt.xticks(np.arange(13))
plt.ylabel('Average stock price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart is a line chart because it effectively visualizes trends over time, making it easier to observe patterns in stock price movements across months. A line chart helps in:
#
#
# 1.  Identifying Trends: Clearly shows periods of stock price growth and decline.
#
# 2.  Comparing Metrics: Displays the relationship between Open, High, Low, and Close prices in a single view.
#
# 3.  Spotting Volatility: Highlights fluctuations and stability in the stock market throughout the year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Peak Performance in Mid-Year: Stock prices (Open, High, Low, Close) increase
#
# 1.   Peak Performance in Mid-Year: Stock prices (Open, High, Low, Close) increase from the beginning of the year, peaking around May–June.
#
# 2.  Gradual Decline in Later Months: A downward trend starts from July onward, with prices consistently dropping until November.
#
# 3.  Lowest Volatility in Year-End: The price variations (High vs. Low) shrink towards year-end, indicating reduced market fluctuations.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Positive Impact: Understanding peak performance periods can help businesses time investments, marketing efforts, and strategic expansions effectively.
#
# *   Negative Impact: The consistent drop after mid-year signals potential seasonal slowdowns, external market pressures, or declining investor confidence, requiring intervention strategies to mitigate financial risks.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a date column, derive the quarter and year
stock_df['Quarter'] = stock_df.index.to_period('Q')
stock_df['Year'] = stock_df.index.year

# Filter data for the last 4 years
last_4_years = stock_df['Year'].unique()[-4:]  # Get the last 4 years
filtered_df = stock_df[stock_df['Year'].isin(last_4_years)]

# Group by quarter and aggregate
quarterly_data = filtered_df.groupby(['Year', 'Quarter']).aggregate(
    {'Open': 'mean', 'High': 'mean', 'Low': 'mean', 'Close': 'mean'}
)

# Plotting the data for each quarter in the last 4 years
fig, ax = plt.subplots(figsize=(16, 8))  # Adjust figsize for better visualization

width = 0.15  # Width of each bar
x_pos = range(len(quarterly_data.index))

ax.bar([x - width * 1.5 for x in x_pos], quarterly_data['Open'], width, label='Open')
ax.bar([x - width * 0.5 for x in x_pos], quarterly_data['High'], width, label='High')
ax.bar([x + width * 0.5 for x in x_pos], quarterly_data['Low'], width, label='Low')
ax.bar([x + width * 1.5 for x in x_pos], quarterly_data['Close'], width, label='Close')

ax.set_xticks(x_pos)
ax.set_xticklabels([f'{year}Q{quarter.quarter}' for year, quarter in quarterly_data.index])  # Format labels
ax.set_ylabel('Average stock price')
ax.set_title('Average Stock Prices by Quarter (Last 4 Years)')
ax.legend()
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This bar chart was chosen because it effectively displays quarterly trends in average stock prices over the past four years, offering valuable business insights:
#
#
#
# *   Trend Analysis: It helps identify periods of growth and decline, assisting in investment and financial planning.
#
# *   Volatility Detection: The differences between high, low, open, and close prices reveal fluctuations in stock performance.
#
# *   Market Health Evaluation: A consistent decline in stock prices could indicate financial distress, while stability or growth suggests positive market sentiment.
#
# *   Strategic Decision-Making: Businesses and investors can use these insights to optimize their buy/sell strategies and risk management approaches.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals a clear declining trend in average stock prices over the last four years, indicating potential market instability or economic downturn. Early quarters show strong stock performance, but a gradual decrease suggests factors like reduced investor confidence, external market pressures, or company-specific challenges. The volatility between high, low, open, and close prices also highlights fluctuating market conditions. Understanding these trends can help businesses and investors make strategic financial decisions to mitigate risks and capitalize on market movements.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a positive business impact by enabling proactive decision-making, such as adjusting investment strategies, optimizing resource allocation, and implementing risk mitigation measures to stabilize stock performance. Businesses can use this data to identify downturn patterns, adjust financial plans, and explore new growth opportunities.
#
# However, the declining trend in stock prices suggests negative growth implications, potentially due to market downturns, economic slowdowns, or industry-specific challenges. A consistent drop in stock prices may indicate declining investor confidence, poor financial performance, or external economic pressures, affecting overall business valuation and future investments. Addressing these concerns through strategic interventions is crucial to prevent further decline and ensure sustainable growth.

# %% [markdown]
# #### Chart - 6

# %%
# Plotting the distributions of Independent features.

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 5))

# Define independent_variables with the intended columns
independent_variables = ['Open', 'High', 'Low'] # Assuming these are the intended independent variables from the 'col' variable in your environment

for i, col in enumerate(independent_variables):
    plt.subplot(1, 3, i+1)
    sns.distplot(stock_df_copy[col], color='b')
    plt.xlabel(col, fontsize=10)

    # Plotting the mean and the median.
    plt.axvline(stock_df_copy[col].mean(), color='yellow')
    plt.axvline(stock_df_copy[col].median(), color='red', linestyle='dashed')

plt.suptitle('Distibution of independent variables')
plt.tight_layout()
plt.show()

# %%
# Distribution of transformed independent variables
plt.figure(figsize=(14, 5))

for i, col in enumerate(independent_variables):
    plt.subplot(1, 3, i+1)
    sns.distplot(np.log10(stock_df_copy[col]), color='b')
    plt.xlabel(col, fontsize=10)

    # Plotting the mean and the median.
    plt.axvline(np.log10(stock_df_copy[col]).mean(), color='yellow')
    plt.axvline(np.log10(stock_df_copy[col]).median(), color='red', linestyle='dashed')

plt.suptitle('Distibution of Transformed independent variables')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected this specific chart because it visually represents the distribution of transformed independent variables (Open, High, Low) in a way that helps evaluate their normality and skewness. This is crucial for financial modeling and machine learning because:
#
#
# *   Checking Normality: Many statistical models and ML algorithms perform better when input variables follow a normal distribution. This chart helps assess whether the transformation was effective.
#
# *   Identifying Skewness & Outliers: The kernel density estimation (KDE) curve and histogram bins highlight skewness or outliers, which can impact predictions.
#
# *   Comparison Across Variables: By plotting three key variables side by side, the chart makes it easy to spot differences and similarities in distributions.
#
# *   Model Readiness: Ensuring that input data is well-behaved can lead to better predictions and more stable business insights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histograms show the distribution of transformed independent variables (Open, High, Low).
#
# All three distributions appear approximately normal, but slightly skewed.
#
# The solid blue line represents the kernel density estimation (KDE), providing a smoothed approximation of the data distribution.
#
# The yellow and red dashed lines represent the mean and median, respectively, indicating that the data is slightly skewed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# A well-distributed dataset improves predictive accuracy for financial modeling and decision-making.
# Better insights into stock price behaviors help in risk assessment and strategy formulation.
#
# ❌ Potential Negative Impact:
#
# If not carefully interpreted, transformed variables might hide real-world anomalies, leading to misleading conclusions.
# A near-normal distribution does not always guarantee accurate financial forecasting, as market behavior can be unpredictable.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# !pip install mplfinance

import mplfinance as mpf

df_candle = stock_df_copy[['Open', 'High', 'Low', 'Close']]

mpf.plot(df_candle, type='candle', style='yahoo', title='Candlestick Chart')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the Candlestick Chart because it provides a detailed visual representation of Yes Bank's stock price movements over time, including open, high, low, and close prices.
#
# This chart effectively illustrates:
#
# ✅ Long-term Price Trends – The stock witnessed a massive uptrend until 2018, followed by a sharp decline.
#
# ✅ Market Volatility – The presence of large candlesticks in certain periods highlights extreme fluctuations in stock prices.
#
# ✅ Investor Sentiment & Decision-Making – Helps traders understand price behavior and spot reversal patterns or trends for strategic trading.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1️⃣ Rapid Growth (2005-2018):
#
# Yes Bank's stock saw steady growth from 2005, reaching a peak in 2018 (~₹400).
# This suggests a strong investor confidence and good financial performance during this period.
#
# 2️⃣ Sharp Decline Post-2018:
#
# After hitting its peak, the stock experienced a massive crash in 2019-2020, dropping below ₹50.
# This suggests financial instability, governance issues, or external economic factors that led to a loss of investor trust.
#
# 3️⃣ High Volatility:
#
# The chart shows long candlesticks and wicks, especially during the downfall, indicating high price fluctuations.
# This could mean panic selling, institutional exits, or regulatory interventions affecting the stock.
#
# 4️⃣ Potential Bottom Formation (Post-2020):
#
# The stock appears to stabilize at lower levels after its crash, suggesting it may have found a bottom.
# This could indicate a potential recovery phase or long-term stagnation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Business Impact:
#
# The early growth phase (2005-2018) reflects strong investor confidence and solid financial performance, attracting new investments and business expansions.
# Understanding past market trends can help in better risk management and future financial planning.
#
# ❌ Negative Growth Insights:
#
# The sharp decline post-2018 indicates governance issues, financial mismanagement, or regulatory challenges, leading to loss of investor trust.
# High volatility discourages long-term investors, affecting stock stability and funding opportunities.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# Plotting the independent variables against dependent variable and checking the correlation between them.
for col in independent_variables:

  fig = plt.figure(figsize=(12, 6))
  ax = fig.gca()
  feature = stock_df_copy[col]
  label = stock_df_copy['Close']
  correlation = feature.corr(label)        # calculating the correlation between dependent variable and independent features.
  plt.scatter(x=feature, y=label)          # plotting dependent variables against independent features.


  plt.xlabel(col)
  plt.ylabel('Close')
  ax.set_title('Close vs ' + col + '- correlation: ' + str(round((correlation),6)))

  z = np.polyfit(stock_df_copy[col], stock_df_copy['Close'], 1)
  y_ = np.poly1d(z)(stock_df_copy[col])

  plt.plot(stock_df_copy[col], y_, "r--", lw=1)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected the Scatter Plot because it visually demonstrates the strong correlation between the opening and closing prices of Yes Bank’s stock. This chart effectively conveys how stock prices tend to move throughout the day and highlights market stability or volatility.
#
# 🔍 Key Reasons for Selection:
#
# ✅ High Correlation Insight – The strong positive trend (red regression line) suggests that opening prices can reliably predict closing prices.
#
# ✅ Market Behavior Understanding – Helps traders and analysts assess price consistency and potential arbitrage opportunities.
#
# ✅ Decision-Making – Investors can use this insight for strategic entry and exit points in stock trading.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   There is a strong positive correlation (0.977971) between Open and Close prices.
#
# *   The data points closely follow the regression line (red dashed line), indicating a linear relationship.
#
# *   Minor deviations suggest market fluctuations, but overall, opening prices are a strong predictor of closing prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Impact:
#
# High correlation helps in forecasting closing prices, benefiting traders, investors, and financial analysts.
# Businesses can use this trend to optimize trading strategies and reduce risks.
#
# ❌ Potential Negative Impact:
#
# Over-reliance on this correlation may not account for market shocks (e.g., unexpected news, economic events).
# Sudden volatility or external factors can disrupt this linear relationship, leading to potential financial losses.

# %% [markdown]
# #### Chart - 9

# %%
# Categorize months based on price movement
stock_df["Price Movement"] = stock_df.apply(lambda row: "Up" if row["Close"] > row["Open"] else "Down", axis=1)

# Count occurrences of "Up" and "Down" movements
movement_counts = stock_df["Price Movement"].value_counts()

# Plot pie chart
plt.figure(figsize=(6, 6))
plt.pie(movement_counts, labels=movement_counts.index, autopct="%1.1f%%", colors=["green", "red"], startangle=90)
plt.title("Yes Bank Stock Up vs. Down Movements")

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the Up vs. Down Movements Pie Chart because it provides a clear, high-level view of Yes Bank's stock trends. Unlike line charts or bar graphs, which show detailed fluctuations, this visually simplifies the overall market behavior in an easy-to-interpret manner.
#
# 🔍 Key Reasons for Selection:
#
# ✅ Quick Comparison – The pie chart instantly shows the balance between stock gains and losses.
#
# ✅ Investor Sentiment – Helps understand whether the stock has an overall upward or downward bias.
#
# ✅ Strategic Decision-Making – Businesses and investors can assess risk vs. reward and plan accordingly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ✔️ Slightly More Upward Movements – The stock has moved up 54.1% of the time, compared to 45.9% down movements.
#
# ✔️ Balanced Market Behavior – While positive movement dominates, the difference isn't extreme, indicating a volatile market.
#
# ✔️ Potential for Growth – The stock has a marginal upward bias, suggesting opportunities for long-term investors.
#
# ✔️ Risk Awareness – The 45.9% downward trend highlights the need for risk management strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 🚀 Positive Business Impact:
#
# The insights suggest that Yes Bank's stock has a slight upward bias (54.1% up vs. 45.9% down), which is promising for investors. This can boost confidence in long-term investments, strategic financial planning, and business growth opportunities. The trend supports a positive outlook if leveraged with risk management.
#
# ⚠️ Insights Leading to Negative Growth:
#
# High Volatility Risk – The 45.9% down movements indicate significant stock price fluctuations, which can discourage risk-averse investors and affect market stability.
#
# Lack of Strong Upward Momentum – While up movements exceed down movements, the margin is narrow, meaning the stock isn't in a strong bullish trend. This limits aggressive expansion strategies.
#
# Investor Uncertainty – If not properly managed, market fluctuations could lead to panic selling, eroding investor trust and leading to negative sentiment in the market.

# %% [markdown]
# Chart - 10

# %%
# Calculate daily returns
stock_df["Daily Returns"] = stock_df["Close"].pct_change()

# Plot daily returns over time, use index for x-axis
plt.figure(figsize=(12, 6))
plt.plot(stock_df.index, stock_df["Daily Returns"], color="blue", label="Daily Returns")
#                     ^^^^^^ Changed from stock_df["Date"] to stock_df.index

# Labels and title
plt.xlabel("Date")
plt.ylabel("Daily Return")
plt.title("Yes Bank Daily Returns Over Time")
plt.axhline(y=0, color="black", linestyle="--", linewidth=1)  # Reference line at 0
plt.legend()
plt.grid()

# Show the plot
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# The Daily Returns Chart was selected because:
#
# 🔹 Captures Market Volatility – It provides a clear view of price fluctuations, highlighting risk factors and market trends.
#
# 🔹 Identifies Trading Opportunities – Helps investors spot periods of high and low returns for better decision-making.
#
# 🔹 Evaluates Stability – A volatile stock can indicate uncertainty, while stable returns build confidence among investors.
#
# 🔹 Risk Assessment Tool – Businesses can use this to develop risk mitigation strategies for sustainable growth.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 📊 1. High Volatility: The chart shows frequent and extreme fluctuations, indicating that Yes Bank’s stock had high-risk, high-reward potential over time.
#
# ⚠️ 2. Sudden Spikes & Dips: There are major return spikes, suggesting sharp market reactions to news events, financial instability, or regulatory actions.
#
# 📉 3. Increased Instability in Later Years: The fluctuations appear to intensify around 2018–2020, correlating with Yes Bank’s financial troubles, signaling increased market uncertainty.
#
# 🔄 4. Potential Trading Strategy: Given these swings, short-term traders could have capitalized on momentum trading while long-term investors faced elevated risk.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# 🔹 Positive Business Impact?
#
# ✅ Yes, if leveraged correctly!
#
# The insights from the daily returns chart can help businesses and investors make informed decisions:
#
# 📊 1. Risk Management: Understanding volatility allows businesses to hedge risks, diversify portfolios, or adjust trading strategies.
#
# 💡 2. Strategic Decision-Making: Investors can use return patterns to time entries and exits, avoiding periods of extreme instability.
#
# 🚀 3. Confidence Boost for Stakeholders: If volatility is controlled, investor trust can be regained, improving the company’s market reputation.
#
# ⚠️ Negative Growth Concern: However, if not addressed, high fluctuations may deter long-term investors, making fundraising and market stability challenging.

# %% [markdown]
# Chart - 11

# %%
# Compute Monthly and Yearly Average Prices
# Assuming 'Date' column is datetime type

stock_df["Year-Month"] = stock_df.index.to_period("M")
stock_df["Year"] = stock_df.index.year

monthly_avg_price = stock_df.groupby("Year-Month")["Close"].mean()
yearly_avg_price = stock_df.groupby("Year")["Close"].mean()

# Convert index to datetime for plotting
monthly_avg_price.index = monthly_avg_price.index.to_timestamp()

# Plot Monthly Average Prices
plt.figure(figsize=(12, 6))
plt.plot(monthly_avg_price.index, monthly_avg_price, color="purple", marker="o", linestyle="-", label="Monthly Avg Price")

# Labels and title
plt.xlabel("Date")
plt.ylabel("Average Closing Price")
plt.title("Yes Bank Monthly Average Closing Price")
plt.legend()
plt.grid()

# Show the plot
plt.show()

# Plot Yearly Average Prices
plt.figure(figsize=(10, 5))
plt.bar(yearly_avg_price.index, yearly_avg_price, color="skyblue", label="Yearly Avg Price")

# Labels and title
plt.xlabel("Year")
plt.ylabel("Average Closing Price")
plt.title("Yes Bank Yearly Average Closing Price")
plt.legend()
plt.grid(axis="y")

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# These charts were picked strategically to tell the complete story of Yes Bank’s stock journey, from its peak to downfall, while uncovering volatility and key correlations for financial insights. 🚀

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1️⃣ Monthly & Yearly Trends Show Rise and Collapse
#
#
#
# Yes Bank’s stock witnessed steady growth until 2018, reaching an all-time high.
# Post-2018, a drastic decline reflects financial instability, governance issues, and investor distrust.
#
# 2️⃣ Early Growth Phases (2004-2014) 🌱
#
# The bank maintained consistent growth, indicating strong business expansion and investor confidence.
#
#
# 3️⃣ 2015-2018 Peak 🚀
#
# Rapid surge in stock prices, driven by high investor sentiment and expansion strategies.
#
#
#
# 4️⃣ 2019-2020 Crash ⚠️
#
# A steep downfall due to financial mismanagement, bad loans, and regulatory concerns.
# This drastic drop eroded investor confidence and impacted long-term stability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ✅ Positive Insights:
#
# Understanding past trends helps in risk assessment and strategic decision-making.
# Investors can identify early warning signs for future investments.
#
#
# ❌ Negative Insights:
#
# The sharp decline highlights corporate governance failures.
# Risk-averse investors may hesitate to invest in banking stocks with similar risk factors.

# %% [markdown]
# Chart - 11

# %%
# Define the Bollinger Bands window (typically 20 days)
bollinger_window = 20

# Compute the Simple Moving Average (SMA)
stock_df["SMA"] = stock_df["Close"].rolling(window=bollinger_window).mean()

# Compute the Standard Deviation
stock_df["Rolling Std"] = stock_df["Close"].rolling(window=bollinger_window).std()

# Compute the Upper and Lower Bollinger Bands
stock_df["Upper Band"] = stock_df["SMA"] + (2 * stock_df["Rolling Std"])
stock_df["Lower Band"] = stock_df["SMA"] - (2 * stock_df["Rolling Std"])

# Plot the Closing Price and Bollinger Bands
plt.figure(figsize=(12, 6))
# If 'Date' is in the index, use stock_df.index:
plt.plot(stock_df.index, stock_df["Close"], color="blue", label="Close Price")
plt.plot(stock_df.index, stock_df["SMA"], color="orange", label="SMA (20-day)")
plt.plot(stock_df.index, stock_df["Upper Band"], color="red", linestyle="--", label="Upper Band")
plt.plot(stock_df.index, stock_df["Lower Band"], color="green", linestyle="--", label="Lower Band")

# Labels and title
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.title("Yes Bank Bollinger Bands (20-Day)")
plt.legend()
plt.grid()

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bollinger Bands were chosen because they provide a powerful visual representation of stock volatility, trend direction, and potential buy/sell signals.
#
# ✅ Tracks Market Volatility ⚡
#
# The bands expand when volatility is high and contract when it’s low, helping traders anticipate market movements.
#
# ✅ Identifies Trading Signals 🔍
#
# Price near the upper band → Overbought (sell signal)
# Price near the lower band → Oversold (buy signal)
#
# ✅ Detects Trend Reversals 🔄
#
# A stock consistently touching the upper band in an uptrend can signal strong bullish momentum.
# A breakdown below the lower band (like in 2018-2020 for Yes Bank) warns of potential crashes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1️⃣ Volatility & Price Movements ⚡
#
# Bollinger Bands expand during periods of high volatility and contract when volatility is low.
# Noticeable wide bands from 2017 to 2020, indicating extreme price movements.
#
#
# 2️⃣ Overbought & Oversold Signals 📉📈
#
# When the Close Price (blue line) touches the upper band (red dashed line) → Stock is overbought (possible reversal).
# When it touches the lower band (green dashed line) → Stock is oversold (potential buying opportunity).
#
# 3️⃣ Significant Trends & Market Crashes 🚀📉
#
# A strong uptrend from 2014 to 2018, with prices mostly near the upper band.
# A sharp decline after 2018, with prices breaking the lower band, signaling a market correction or crisis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 📊 Business Impact of Yes Bank Stock Insights
#
# ✅ Positive Impact:
#
# Trend Analysis 📈 → Helps investors make data-driven decisions on entry/exit points.
#
# Volatility Insights ⚡ → Assists in risk management and strategic planning.
#
# Bollinger Bands Signals 🔍 → Identify profitable buy/sell opportunities for traders.
#
#
# ------
#
#
#
#
# ❌ Negative Growth Indicators:
#
# Post-2018 Crash 📉 → Sudden price drop suggests financial instability or governance issues.
#
# High Volatility ⚠️ → Increased fluctuations may discourage long-term investors.
#
# Oversold Conditions ⛔ → Continuous lower-band touches indicate weak investor confidence.

# %% [markdown]
# Chart 12 - Correlation Heatmap

# %%
# Chart - 12 visualization code


plt.figure(figsize=(12, 8))
sns.heatmap(stock_df_copy.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is one of the best ways to visually analyze relationships between numerical variables. Here's why it was chosen for this analysis:
#
# ✅ Reveals Hidden Relationships 📊
#
#
# The heatmap highlights how strongly stock prices (Open, High, Low, Close) move together.
# Instead of manually calculating correlations, this visualization makes patterns clear at a glance.
#
#
# ✅ Easy to Interpret 🎨
#
# The color gradient instantly shows strong vs. weak correlations.
# Darker shades indicate a stronger relationship, helping us focus on the most important insights.
#
# ✅ Useful for Stock Market Analysis 📈
#
# Since stock prices are interdependent, a correlation heatmap helps identify predictable price movements.
# Traders and analysts can use this to develop better forecasting models.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1️⃣ Stock Prices are Highly Correlated 📈
#
# The Open, High, Low, and Close prices are strongly correlated (values close to 1.00).
# This indicates that if the stock opens high, it is likely to close high, and vice versa.
#
# 2️⃣ Close Price is Closely Linked to Low & High Prices 🔍
#
# The Close price has nearly perfect correlation (~0.99) with High and Low prices.
# This suggests that daily price fluctuations tend to follow a predictable range.
#
# 3️⃣ Market Predictability 📊
#
# The high correlation means Yes Bank's stock follows a consistent price movement pattern.
# Traders can use opening prices to estimate closing prices, helping in intraday trading decisions.

# %% [markdown]
# #### Chart - 13 - Pair Plot

# %%
# Pair Plot visualization code

# Create the pair plot
sns.pairplot(stock_df_copy, kind="scatter", diag_kind="kde")

plt.suptitle('Pair Plot of Stock Data')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the pair plot because it effectively visualizes:
#
# Correlations: Shows how Open, High, Low, and Close prices move together.
#
# 1.   Correlations: Shows how Open, High, Low, and Close prices move together.
#
# 2.   Distributions: Reveals the shape of price distributions (e.g., skewness, spread).
#
# 3.   Outliers: Identifies any unusual stock price movements.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Strong positive correlations between Open, High, Low, and Close prices, indicating that they move together.
#
# The distributions show that most stock prices are concentrated in the lower range, with a few higher values (right-skewed).
#
# Some outliers suggest occasional extreme price movements.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the analysis of Yes Bank's stock price trends, the following strategic recommendations can help the client achieve business objectives:
#
# 1. Strengthen Financial Stability & Governance
#
#   Improve asset quality by reducing Non-Performing Assets (NPAs).
#   Implement strong corporate governance to regain investor trust.
#   Maintain transparent financial disclosures to prevent speculation-driven market movements.
#
# 2. Enhance Investor Confidence
#
#   Offer dividend incentives or buybacks to attract long-term investors.
#   Strengthen relations with institutional investors for stable stock performance.
#   Improve communication strategies to counter negative media perception.
#
# 3. Drive Sustainable Growth
#
#   Focus on diversified revenue streams, reducing dependency on risky corporate loans.
#   Expand retail banking and digital banking services for a broader customer base.
#   Strengthen risk management frameworks to prevent future financial crises.
#
# 4. Leverage Market Trends for Stock Recovery
#
#   Identify strategic partners for potential mergers or acquisitions.
#   Develop a strong recovery roadmap and ensure compliance with RBI regulations.
#   Capitalize on Fintech collaborations to boost digital transactions and customer engagement.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The exploratory data analysis (EDA) of Yes Bank’s stock price reveals critical insights into its historical trends, volatility, and key turning points. The stock showed significant growth until 2018, followed by a steep decline due to financial instability, governance issues, and regulatory interventions.
#
# Key takeaways include:
#
# ✅ High Volatility: The stock experienced sharp price fluctuations, especially around 2019-2020, indicating market uncertainty and investor concerns.
#
# ✅ Drastic Decline: A major drop in stock price post-2018 highlights financial distress, increasing NPAs, and loss of investor confidence.
#
# ✅ Temporary Spikes: Short-term price surges suggest market reactions to specific news, government bailouts, and restructuring efforts.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
